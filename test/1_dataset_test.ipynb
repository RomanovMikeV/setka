# %%
import sys
sys.path.append('../src')

# %%
## Инициализация датасета

import dataset_template as dataset
my_dataset = dataset.DataSet()

# %%
print(len(my_dataset), '<- Количество элементов в датасете')
input, target = my_dataset[0]
